# %% [markdown]
# --- Day 4: The Ideal Stocking Stuffer ---
#
# Santa needs help mining some AdventCoins (very similar to bitcoins) to use as gifts for all the economically forward-thinking little girls and boys.
#
# To do this, he needs to find MD5 hashes which, in hexadecimal, start with at least five zeroes. The input to the MD5 hash is some secret key (your puzzle input, given below) followed by a number in decimal. To mine AdventCoins, you must find Santa the lowest positive number (no leading zeroes: 1, 2, 3, ...) that produces such a hash.
#
# For example:
#
# If your secret key is abcdef, the answer is 609043, because the MD5 hash of abcdef609043 starts with five zeroes (000001dbbfa...), and it is the lowest such number to do so.
# If your secret key is pqrstuv, the lowest number it combines with to make an MD5 hash starting with five zeroes is 1048970; that is, the MD5 hash of pqrstuv1048970 looks like 000006136ef....

# %%
import hashlib
# Open data input file
with open('input.txt','r') as fh:
    data = [line.strip() for line in fh]
    print(data)
print(len(data))
# Out:
# ['yzbqklnj']
# 1

# %%
#Data Stream - Single input
datastream = data[0]
print(datastream)
answer = 0
hash = 0
counter = 0
 
while True:
    
    secret = datastream + str(answer)
    hash = hashlib.md5(secret.encode('utf-8')).hexdigest()
    # print(hash[0:5])
    # print(hash[5:6])
    
    
    if counter == 100000:
        print('Progress report...')
        print('counted through: ',answer)
        counter = 0
    counter += 1
    if hash[0:5] == '00000' and int(hash[5:6]) > 0:
        print('Hash: ',hash)
        print('Secret: ',secret)
        print ('Answer: ', answer)
        break
    answer += 1
# Out:
# yzbqklnj
# Progress report...
# counted through:  100000
# Progress report...
# counted through:  200000
# Hash:  000002c655df7738246e88f6c1c43eb7
# Secret:  yzbqklnj282749
# Answer:  282749

# %% [markdown]
# --- Part Two ---
#
# Now find one that starts with six zeroes.

# %%
#Data Stream - Single input
datastream = data[0]
print(datastream)
answer = 0
hash = 0
counter = 0
 
while True:
    
    secret = datastream + str(answer)
    hash = hashlib.md5(secret.encode('utf-8')).hexdigest()
    # print(hash[0:5])
    # print(hash[5:6])
    
    
    if counter == 100000:
        print('Progress report...')
        print('counted through: ',answer)
        counter = 0
    counter += 1
    if hash[0:6] == '000000' and int(hash[6:7]) > 0:
        print('Hash: ',hash)
        print('Secret: ',secret)
        print ('Answer: ', answer)
        break
    answer += 1
# Out:
# yzbqklnj
# Progress report...
# counted through:  100000
# Progress report...
# counted through:  200000
# Progress report...
# counted through:  300000
# Progress report...
# counted through:  400000
# Progress report...
# counted through:  500000
# Progress report...
# counted through:  600000
# Progress report...
# counted through:  700000
# Progress report...
# counted through:  800000
# Progress report...
# counted through:  900000
# Progress report...
# counted through:  1000000
# Progress report...
# counted through:  1100000
# Progress report...
# counted through:  1200000
# Progress report...
# counted through:  1300000
# Progress report...
# counted through:  1400000
# Progress report...
# counted through:  1500000
# Progress report...
# counted through:  1600000
# Progress report...
# counted through:  1700000
# Progress report...
# counted through:  1800000
# Progress report...
# counted through:  1900000
# Progress report...
# counted through:  2000000
# ...
